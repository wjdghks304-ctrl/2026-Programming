# %% [markdown]
# <a href="https://colab.research.google.com/github/wjdghks304-ctrl/2026-Programming/blob/main/1%EC%A3%BC%EC%B0%A8_%EA%B9%83%ED%97%88%EB%B8%8C_%EC%A0%80%EC%9E%A5%EC%86%8C%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!

# %%
#구구단 출력
number = int(input("숫자를 입력하세요.:"))

for i in range(1,10):
  print(f"{number} X {i} = {number*i}")
# Out:
# 숫자를 입력하세요.:5
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
